# %%
import requests

url = "https://api-football-v1.p.rapidapi.com/v3/players"

querystring = {"team":"541","search":"ronaldo","season":2014}

headers = {
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com",
	"X-RapidAPI-Key": API_KEY
}

ronaldoresponse = requests.request("GET", url, headers=headers, params=querystring)

print(ronaldoresponse.text)
# Out:
# {"get":"players","parameters":{"team":"541","search":"ronaldo","season":"2014"},"errors":[],"results":1,"paging":{"current":1,"total":1},"response":[{"player":{"id":874,"name":"Cristiano Ronaldo","firstname":"Cristiano Ronaldo","lastname":"dos Santos Aveiro","age":37,"birth":{"date":"1985-02-05","place":"Funchal","country":"Portugal"},"nationality":"Portugal","height":"187 cm","weight":"83 kg","injured":false,"photo":"https:\/\/media.api-sports.io\/football\/players\/874.png"},"statistics":[{"team":{"id":541,"name":"Real Madrid","logo":"https:\/\/media.api-sports.io\/football\/teams\/541.png"},"league":{"id":140,"name":"La Liga","country":"Spain","logo":"https:\/\/media.api-sports.io\/football\/leagues\/140.png","flag":"https:\/\/media.api-sports.io\/flags\/es.svg","season":2014},"games":{"appearences":35,"lineups":35,"minutes":3099,"number":null,"position":"Attacker","rating":null,"captain":false},"substitutes":{"in":0,"out":3,"bench":0},"shots":{"total":null,"on":null},"goals":{"to
# ...

# %%
import pprint

# %%
pprint.pprint(ronaldoresponse.text)
# Out:
# ('{"get":"players","parameters":{"search":"ronaldo","team":"541"},"errors":[],"results":2,"paging":{"current":1,"total":1},"response":[{"player":{"id":874,"name":"Cristiano '
#  'Ronaldo","firstname":"Cristiano Ronaldo","lastname":"dos Santos '
#  'Aveiro","age":37,"birth":{"date":"1985-02-05","place":"Funchal","country":"Portugal"},"nationality":"Portugal","height":"187 '
#  'cm","weight":"83 '
#  'kg","injured":false,"photo":"https:\\/\\/media.api-sports.io\\/football\\/players\\/874.png"},"statistics":[{"team":{"id":541,"name":"Real '
#  'Madrid","logo":"https:\\/\\/media.api-sports.io\\/football\\/teams\\/541.png"},"league":{"id":140,"name":"La '
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(ronaldoresponse)

# %%
pprint.pprint(ronaldoresponse.json())
# Out:
# {'errors': [],
#  'get': 'players',
#  'paging': {'current': 1, 'total': 1},
#  'parameters': {'search': 'ronaldo', 'season': '2014', 'team': '541'},
#  'response': [{'player': {'age': 37,
#                           'birth': {'country': 'Portugal',
#                                     'date': '1985-02-05',
#                                     'place': 'Funchal'},
#                           'firstname': 'Cristiano Ronaldo',
#                           'height': '187 cm',
#                           'id': 874,
#                           'injured': False,
#                           'lastname': 'dos Santos Aveiro',
#                           'name': 'Cristiano Ronaldo',
#                           'nationality': 'Portugal',
#                           'photo': 'https://media.api-sports.io/football/players/874.png',
#                           'weight': '83 kg'},
#                'statistics': [{'cards': {'red': 1, 'yellow': 5, 'yellowred': 0},
# ...

# %%
df.iloc[0,0]
# Out:
# b'{"get":"players","parameters":{"team":"541","search":"ronaldo","season":"2014"},"errors":[],"results":1,"paging":{"current":1,"t'

# %%
df
# Out:
#                                                     0
# 0   b'{"get":"players","parameters":{"team":"541",...
# 1   b'otal":1},"response":[{"player":{"id":874,"na...
# 2   b'o","age":37,"birth":{"date":"1985-02-05","pl...
# 3   b'ght":"83 kg","injured":false,"photo":"https:...
# 4   b'1,"name":"Real Madrid","logo":"https:\\/\\/m...
# 5   b'untry":"Spain","logo":"https:\\/\\/media.api...
# 6   b'es.svg","season":2014},"games":{"appearences...
# 7   b'captain":false},"substitutes":{"in":0,"out":...
# 8   b'ssists":null,"saves":null},"passes":{"total"...
# 9   b'ns":null},"duels":{"total":null,"won":null},...
# 10  b'tted":null},"cards":{"yellow":5,"yellowred":...
# 11  b':null}},{"team":{"id":541,"name":"Real Madri...
# 12  b'null,"name":"Copa del Rey","country":null,"l...
# 13  b'nutes":117,"number":null,"position":"Attacke...
# 14  b'"total":null,"on":null},"goals":{"total":1,"...
# 15  b'acy":null},"tackles":{"total":null,"blocks":...
# ...

# %%
df
# Out:
#                                                     0
# 0   b'{"get":"players","parameters":{"team":"541",...
# 1   b'otal":1},"response":[{"player":{"id":874,"na...
# 2   b'o","age":37,"birth":{"date":"1985-02-05","pl...
# 3   b'ght":"83 kg","injured":false,"photo":"https:...
# 4   b'1,"name":"Real Madrid","logo":"https:\\/\\/m...
# 5   b'untry":"Spain","logo":"https:\\/\\/media.api...
# 6   b'es.svg","season":2014},"games":{"appearences...
# 7   b'captain":false},"substitutes":{"in":0,"out":...
# 8   b'ssists":null,"saves":null},"passes":{"total"...
# 9   b'ns":null},"duels":{"total":null,"won":null},...
# 10  b'tted":null},"cards":{"yellow":5,"yellowred":...
# 11  b':null}},{"team":{"id":541,"name":"Real Madri...
# 12  b'null,"name":"Copa del Rey","country":null,"l...
# 13  b'nutes":117,"number":null,"position":"Attacke...
# 14  b'"total":null,"on":null},"goals":{"total":1,"...
# 15  b'acy":null},"tackles":{"total":null,"blocks":...
# ...

# %%
import requests

url = "https://api-football-v1.p.rapidapi.com/v3/teams"

querystring = {"name":"brazil"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"get":"teams","parameters":{"name":"brazil"},"errors":[],"results":1,"paging":{"current":1,"total":1},"response":[{"team":{"id":6,"name":"Brazil","code":"BRA","country":"Brazil","founded":1914,"national":true,"logo":"https:\/\/media.api-sports.io\/football\/teams\/6.png"},"venue":{"id":204,"name":"Estadio Jornalista M\u00e1rio Filho (Maracan\u00e3)","address":"Rua Professor Eurico Rabelo, Maracan\u00e3","city":"Rio de Janeiro, Rio de Janeiro","capacity":78838,"surface":"grass","image":"https:\/\/media.api-sports.io\/football\/venues\/204.png"}}]}

# %%
import requests

url = "https://api-football-v1.p.rapidapi.com/v3/fixtures"

querystring = {"season":"2022","team":"6"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"get":"fixtures","parameters":{"season":"2022","team":"6"},"errors":[],"results":24,"paging":{"current":1,"total":1},"response":[{"fixture":{"id":293578,"referee":"L. Gonz\u00e1lez","timezone":"UTC","date":"2020-10-10T00:30:00+00:00","timestamp":1602289800,"periods":{"first":1602289800,"second":1602293400},"venue":{"id":11531,"name":"Neo Qu\u00edmica Arena","city":"S\u00e3o Paulo, S\u00e3o Paulo"},"status":{"long":"Match Finished","short":"FT","elapsed":90}},"league":{"id":34,"name":"World Cup - Qualification South America","country":"World","logo":"https:\/\/media.api-sports.io\/football\/leagues\/34.png","flag":null,"season":2022,"round":"Group Stage - 1"},"teams":{"home":{"id":6,"name":"Brazil","logo":"https:\/\/media.api-sports.io\/football\/teams\/6.png","winner":true},"away":{"id":2381,"name":"Bolivia","logo":"https:\/\/media.api-sports.io\/football\/teams\/2381.png","winner":false}},"goals":{"home":5,"away":0},"score":{"halftime":{"home":2,"away":0},"fulltime":{"home":5,"away
# ...

# %%
json = response.json()

# %%
json
# Out:
# {'get': 'fixtures',
#  'parameters': {'season': '2022', 'team': '6'},
#  'errors': [],
#  'results': 24,
#  'paging': {'current': 1, 'total': 1},
#  'response': [{'fixture': {'id': 293578,
#     'referee': 'L. González',
#     'timezone': 'UTC',
#     'date': '2020-10-10T00:30:00+00:00',
#     'timestamp': 1602289800,
#     'periods': {'first': 1602289800, 'second': 1602293400},
#     'venue': {'id': 11531,
#      'name': 'Neo Química Arena',
#      'city': 'São Paulo, São Paulo'},
#     'status': {'long': 'Match Finished', 'short': 'FT', 'elapsed': 90}},
#    'league': {'id': 34,
#     'name': 'World Cup - Qualification South America',
#     'country': 'World',
#     'logo': 'https://media.api-sports.io/football/leagues/34.png',
#     'flag': None,
#     'season': 2022,
#     'round': 'Group Stage - 1'},
#    'teams': {'home': {'id': 6,
#      'name': 'Brazil',
#      'logo': 'https://media.api-sports.io/football/teams/6.png',
#      'winner': True},
#     'away': {'id': 2381,
# ...

# %%
json.keys()
# Out:
# dict_keys(['get', 'parameters', 'errors', 'results', 'paging', 'response'])

# %%
json['get']
# Out:
# 'fixtures'

# %%
json['parameters']
# Out:
# {'season': '2022', 'team': '6'}

# %%
json['errors']
# Out:
# []

# %%
json['results']
# Out:
# 24

# %%
json['response'][0]
# Out:
# {'fixture': {'id': 293578,
#   'referee': 'L. González',
#   'timezone': 'UTC',
#   'date': '2020-10-10T00:30:00+00:00',
#   'timestamp': 1602289800,
#   'periods': {'first': 1602289800, 'second': 1602293400},
#   'venue': {'id': 11531,
#    'name': 'Neo Química Arena',
#    'city': 'São Paulo, São Paulo'},
#   'status': {'long': 'Match Finished', 'short': 'FT', 'elapsed': 90}},
#  'league': {'id': 34,
#   'name': 'World Cup - Qualification South America',
#   'country': 'World',
#   'logo': 'https://media.api-sports.io/football/leagues/34.png',
#   'flag': None,
#   'season': 2022,
#   'round': 'Group Stage - 1'},
#  'teams': {'home': {'id': 6,
#    'name': 'Brazil',
#    'logo': 'https://media.api-sports.io/football/teams/6.png',
#    'winner': True},
#   'away': {'id': 2381,
#    'name': 'Bolivia',
#    'logo': 'https://media.api-sports.io/football/teams/2381.png',
#    'winner': False}},
#  'goals': {'home': 5, 'away': 0},
#  'score': {'halftime': {'home': 2, 'away': 0},
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(json['response'][0])

# %%
json['response'][0].keys()
# Out:
# dict_keys(['fixture', 'league', 'teams', 'goals', 'score'])

# %%
json['response'][0]['fixture']['date']
# Out:
# '2020-10-10T00:30:00+00:00'

# %%
fixture_dates = []
for i in range(len(json['response'])):
    fixture_dates.append(json['response'][i]['fixture']['date'])

# %%
fixture_dates
# Out:
# ['2020-10-10T00:30:00+00:00',
#  '2020-10-14T00:00:00+00:00',
#  '2020-11-14T00:30:00+00:00',
#  '2020-11-17T23:00:00+00:00',
#  '2021-10-10T21:00:00+00:00',
#  '2021-09-05T19:00:00+00:00',
#  '2021-06-05T00:30:00+00:00',
#  '2021-06-09T00:30:00+00:00',
#  '2021-09-03T01:00:00+00:00',
#  '2021-09-10T00:30:00+00:00',
#  '2021-10-07T23:30:00+00:00',
#  '2021-10-15T00:30:00+00:00',
#  '2021-11-12T00:30:00+00:00',
#  '2021-11-16T23:30:00+00:00',
#  '2022-01-27T21:00:00+00:00',
#  '2022-02-02T00:30:00+00:00',
#  '2022-03-24T23:30:00+00:00',
#  '2022-03-30T23:30:00+00:00',
#  '2022-11-24T19:00:00+00:00',
#  '2022-11-28T16:00:00+00:00',
#  '2022-12-02T19:00:00+00:00',
#  '2022-06-11T08:00:00+00:00',
#  '2022-06-06T10:20:00+00:00',
#  '2022-06-02T11:00:00+00:00']

# %%
len(json['response'])
# Out:
# 24

# %%
json['response'][20]
# Out:
# {'fixture': {'id': 855771,
#   'referee': None,
#   'timezone': 'UTC',
#   'date': '2022-12-02T19:00:00+00:00',
#   'timestamp': 1670007600,
#   'periods': {'first': None, 'second': None},
#   'venue': {'id': None, 'name': 'Lusail Iconic Stadium', 'city': 'Lusail'},
#   'status': {'long': 'Not Started', 'short': 'NS', 'elapsed': None}},
#  'league': {'id': 1,
#   'name': 'World Cup',
#   'country': 'World',
#   'logo': 'https://media.api-sports.io/football/leagues/1.png',
#   'flag': None,
#   'season': 2022,
#   'round': 'Group Stage - 3'},
#  'teams': {'home': {'id': 1530,
#    'name': 'Cameroon',
#    'logo': 'https://media.api-sports.io/football/teams/1530.png',
#    'winner': None},
#   'away': {'id': 6,
#    'name': 'Brazil',
#    'logo': 'https://media.api-sports.io/football/teams/6.png',
#    'winner': None}},
#  'goals': {'home': None, 'away': None},
#  'score': {'halftime': {'home': None, 'away': None},
#   'fulltime': {'home': None, 'away': None},
# ...

# %%
import requests

url = "https://api-football-v1.p.rapidapi.com/v3/predictions"

querystring = {"fixture":"855771"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "api-football-v1.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"get":"predictions","parameters":{"fixture":"855771"},"errors":[],"results":1,"paging":{"current":1,"total":1},"response":[{"predictions":{"winner":{"id":6,"name":"Brazil","comment":"Win or draw"},"win_or_draw":true,"under_over":null,"goals":{"home":null,"away":null},"advice":"Double chance : draw or Brazil","percent":{"home":"0%","draw":"50%","away":"50%"}},"league":{"id":1,"name":"World Cup","country":"World","logo":"https:\/\/media.api-sports.io\/football\/leagues\/1.png","flag":null,"season":2022},"teams":{"home":{"id":1530,"name":"Cameroon","logo":"https:\/\/media.api-sports.io\/football\/teams\/1530.png","last_5":{"form":"0%","att":"0%","def":"0%","goals":{"for":{"total":0,"average":"0.0"},"against":{"total":0,"average":"0.0"}}},"league":{"form":null,"fixtures":{"played":{"home":0,"away":0,"total":0},"wins":{"home":0,"away":0,"total":0},"draws":{"home":0,"away":0,"total":0},"loses":{"home":0,"away":0,"total":0}},"goals":{"for":{"total":{"home":0,"away":0,"total":0},"average":{
# ...

# %%
pred = response.json()

# %%
pred['response'][0].keys()
# Out:
# dict_keys(['predictions', 'league', 'teams', 'comparison', 'h2h'])

# %%
pred['response'][0]['h2h'][0]
# Out:
# {'fixture': {'id': 225575,
#   'referee': 'Michael Oliver, England',
#   'timezone': 'UTC',
#   'date': '2018-11-20T19:30:00+00:00',
#   'timestamp': 1542742200,
#   'periods': {'first': 1542742200, 'second': 1542745800},
#   'venue': {'id': None, 'name': 'Stadium MK', 'city': 'Milton Keynes'},
#   'status': {'long': 'Match Finished', 'short': 'FT', 'elapsed': 90}},
#  'league': {'id': 10,
#   'name': 'Friendlies',
#   'country': 'World',
#   'logo': 'https://media.api-sports.io/football/leagues/10.png',
#   'flag': None,
#   'season': 2018,
#   'round': 'Friendlies 1'},
#  'teams': {'home': {'id': 6,
#    'name': 'Brazil',
#    'logo': 'https://media.api-sports.io/football/teams/6.png',
#    'winner': True},
#   'away': {'id': 1530,
#    'name': 'Cameroon',
#    'logo': 'https://media.api-sports.io/football/teams/1530.png',
#    'winner': False}},
#  'goals': {'home': 1, 'away': 0},
#  'score': {'halftime': {'home': 1, 'away': 0},
#   'fulltime': {'home': 1, 'away': 0},
# ...

# %%
pred['response'][0]['predictions']
# Out:
# {'winner': {'id': 6, 'name': 'Brazil', 'comment': 'Win or draw'},
#  'win_or_draw': True,
#  'under_over': None,
#  'goals': {'home': None, 'away': None},
#  'advice': 'Double chance : draw or Brazil',
#  'percent': {'home': '0%', 'draw': '50%', 'away': '50%'}}

# %%
pred['response'][0]['teams']['home']
# Out:
# {'id': 1530,
#  'name': 'Cameroon',
#  'logo': 'https://media.api-sports.io/football/teams/1530.png',
#  'last_5': {'form': '0%',
#   'att': '0%',
#   'def': '0%',
#   'goals': {'for': {'total': 0, 'average': '0.0'},
#    'against': {'total': 0, 'average': '0.0'}}},
#  'league': {'form': None,
#   'fixtures': {'played': {'home': 0, 'away': 0, 'total': 0},
#    'wins': {'home': 0, 'away': 0, 'total': 0},
#    'draws': {'home': 0, 'away': 0, 'total': 0},
#    'loses': {'home': 0, 'away': 0, 'total': 0}},
#   'goals': {'for': {'total': {'home': 0, 'away': 0, 'total': 0},
#     'average': {'home': '0.0', 'away': '0.0', 'total': '0.0'},
#     'minute': {'0-15': {'total': None, 'percentage': None},
#      '16-30': {'total': None, 'percentage': None},
#      '31-45': {'total': None, 'percentage': None},
#      '46-60': {'total': None, 'percentage': None},
#      '61-75': {'total': None, 'percentage': None},
#      '76-90': {'total': None, 'percentage': None},
# ...

# %%
import requests

url = "https://flashscore.p.rapidapi.com/v1/search/multi-search"

querystring = {"query":"brazil","locale":"en_GB"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "flashscore.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# [{"ID":"I9l9aqLq","TYPE":"participants","SPORT_ID":1,"FAVOURITE_KEY":"1_I9l9aqLq","FLAG_ID":3,"COUNTRY_ID":3,"URL":"brazil","IMAGE":"https://www.flashscore.com/res/image/data/hCaVxehl-4GYKBvjG.png","PARTICIPANT_TYPE_ID":1,"GENDER_ID":1,"NAME":"Brazil","COUNTRY_NAME":"South America","TITLE":"Brazil","TOURNAMENT_STAGE_IDS_WITH_STATS_DATA":[]},{"ID":"f1BgtqZs","TYPE":"participants","SPORT_ID":1,"FAVOURITE_KEY":"1_f1BgtqZs","FLAG_ID":3,"COUNTRY_ID":3,"URL":"brazil","IMAGE":"https://www.flashscore.com/res/image/data/lK51tQYg-rRiXyfJg.png","PARTICIPANT_TYPE_ID":1,"GENDER_ID":1,"NAME":"Brazil U21","COUNTRY_NAME":"South America","TITLE":"Brazil U21","TOURNAMENT_STAGE_IDS_WITH_STATS_DATA":[]},{"ID":"QiTr4PVe","TYPE":"participants","SPORT_ID":1,"FAVOURITE_KEY":"1_QiTr4PVe","FLAG_ID":3,"COUNTRY_ID":3,"URL":"brazil","IMAGE":"https://www.flashscore.com/res/image/data/raiWzzXg-M31iPfhC.png","PARTICIPANT_TYPE_ID":1,"GENDER_ID":1,"NAME":"Brazil U20","COUNTRY_NAME":"South America","TITLE":"Brazil U20
# ...

# %%
json = response.json()

# %%
json
# Out:
# [{'ID': 'I9l9aqLq',
#   'TYPE': 'participants',
#   'SPORT_ID': 1,
#   'FAVOURITE_KEY': '1_I9l9aqLq',
#   'FLAG_ID': 3,
#   'COUNTRY_ID': 3,
#   'URL': 'brazil',
#   'IMAGE': 'https://www.flashscore.com/res/image/data/hCaVxehl-4GYKBvjG.png',
#   'PARTICIPANT_TYPE_ID': 1,
#   'GENDER_ID': 1,
#   'NAME': 'Brazil',
#   'COUNTRY_NAME': 'South America',
#   'TITLE': 'Brazil',
#   'TOURNAMENT_STAGE_IDS_WITH_STATS_DATA': []},
#  {'ID': 'f1BgtqZs',
#   'TYPE': 'participants',
#   'SPORT_ID': 1,
#   'FAVOURITE_KEY': '1_f1BgtqZs',
#   'FLAG_ID': 3,
#   'COUNTRY_ID': 3,
#   'URL': 'brazil',
#   'IMAGE': 'https://www.flashscore.com/res/image/data/lK51tQYg-rRiXyfJg.png',
#   'PARTICIPANT_TYPE_ID': 1,
#   'GENDER_ID': 1,
#   'NAME': 'Brazil U21',
#   'COUNTRY_NAME': 'South America',
#   'TITLE': 'Brazil U21',
#   'TOURNAMENT_STAGE_IDS_WITH_STATS_DATA': []},
#  {'ID': 'QiTr4PVe',
#   'TYPE': 'participants',
#   'SPORT_ID': 1,
#   'FAVOURITE_KEY': '1_QiTr4PVe',
#   'FLAG_ID': 3,
# ...

# %%
import requests

url = "https://flashscore.p.rapidapi.com/v1/teams/fixtures"

querystring = {"team_id":"I9l9aqLq","sport_id":"1","locale":"en_GB","page":"1"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "flashscore.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"DATA":[{"NAME":"South America: World Cup - Qualification","HEADER":"South America: World Cup - Qualification;156;KC7EZIGl","NAME_PART_1":"South America","NAME_PART_2":"World Cup - Qualification","TOURNAMENT_TEMPLATE_ID":"lvUBR5F8","COUNTRY_ID":8,"COUNTRY_NAME":"World","TOURNAMENT_STAGE_ID":"KC7EZIGl","TOURNAMENT_TYPE":"t","TOURNAMENT_ID":"fRgR6gtF","SOURCE_TYPE":0,"HAS_LIVE_TABLE":0,"STANDING_INFO":1,"TEMPLATE_ID":"3_lvUBR5F8","TOURNAMENT_STAGE_TYPE":2,"SHORT_NAME":"World Cup","URL":"/football/world/world-cup/","TOURNAMENT_IMAGE":"https://www.flashscore.com/res/image/data/hjGIig9j-rDxt866M.png","SORT":"00South Americ013merica0000000100001000World Cup   009ld Cup000","STAGES_COUNT":0,"ZKL":"hjGIig9j-rDxt866M.png","ZKU":"world-cup","TOURNAMENT_SEASON_ID":"fRgR6gtF","CATEGORY_NAME":"South America","EVENTS":[{"EVENT_ID":"h6ohk5Fb","START_TIME":1663866000,"START_UTIME":1663866000,"STAGE_TYPE":"SCHEDULED","MERGE_STAGE_TYPE":"SCHEDULED","STAGE":"SCHEDULED","SORT":"Brazil","ROUND":"Round 6
# ...

# %%
json = response.json()
json
# Out:
# {'DATA': [{'NAME': 'South America: World Cup - Qualification',
#    'HEADER': 'South America: World Cup - Qualification;156;KC7EZIGl',
#    'NAME_PART_1': 'South America',
#    'NAME_PART_2': 'World Cup - Qualification',
#    'TOURNAMENT_TEMPLATE_ID': 'lvUBR5F8',
#    'COUNTRY_ID': 8,
#    'COUNTRY_NAME': 'World',
#    'TOURNAMENT_STAGE_ID': 'KC7EZIGl',
#    'TOURNAMENT_TYPE': 't',
#    'TOURNAMENT_ID': 'fRgR6gtF',
#    'SOURCE_TYPE': 0,
#    'HAS_LIVE_TABLE': 0,
#    'STANDING_INFO': 1,
#    'TEMPLATE_ID': '3_lvUBR5F8',
#    'TOURNAMENT_STAGE_TYPE': 2,
#    'SHORT_NAME': 'World Cup',
#    'URL': '/football/world/world-cup/',
#    'TOURNAMENT_IMAGE': 'https://www.flashscore.com/res/image/data/hjGIig9j-rDxt866M.png',
#    'SORT': '00South Americ013merica0000000100001000World Cup   009ld Cup000',
#    'STAGES_COUNT': 0,
#    'ZKL': 'hjGIig9j-rDxt866M.png',
#    'ZKU': 'world-cup',
#    'TOURNAMENT_SEASON_ID': 'fRgR6gtF',
#    'CATEGORY_NAME': 'South America',
# ...

# %%
json.keys()
# Out:
# dict_keys(['DATA'])

# %%
json['DATA'][0]
# Out:
# {'NAME': 'South America: World Cup - Qualification',
#  'HEADER': 'South America: World Cup - Qualification;156;KC7EZIGl',
#  'NAME_PART_1': 'South America',
#  'NAME_PART_2': 'World Cup - Qualification',
#  'TOURNAMENT_TEMPLATE_ID': 'lvUBR5F8',
#  'COUNTRY_ID': 8,
#  'COUNTRY_NAME': 'World',
#  'TOURNAMENT_STAGE_ID': 'KC7EZIGl',
#  'TOURNAMENT_TYPE': 't',
#  'TOURNAMENT_ID': 'fRgR6gtF',
#  'SOURCE_TYPE': 0,
#  'HAS_LIVE_TABLE': 0,
#  'STANDING_INFO': 1,
#  'TEMPLATE_ID': '3_lvUBR5F8',
#  'TOURNAMENT_STAGE_TYPE': 2,
#  'SHORT_NAME': 'World Cup',
#  'URL': '/football/world/world-cup/',
#  'TOURNAMENT_IMAGE': 'https://www.flashscore.com/res/image/data/hjGIig9j-rDxt866M.png',
#  'SORT': '00South Americ013merica0000000100001000World Cup   009ld Cup000',
#  'STAGES_COUNT': 0,
#  'ZKL': 'hjGIig9j-rDxt866M.png',
#  'ZKU': 'world-cup',
#  'TOURNAMENT_SEASON_ID': 'fRgR6gtF',
#  'CATEGORY_NAME': 'South America',
#  'EVENTS': [{'EVENT_ID': 'h6ohk5Fb',
#    'START_TIME': 1663866000,
# ...

# %%
json['DATA'][1].keys()
# Out:
# dict_keys(['NAME', 'HEADER', 'NAME_PART_1', 'NAME_PART_2', 'TOURNAMENT_TEMPLATE_ID', 'COUNTRY_ID', 'COUNTRY_NAME', 'TOURNAMENT_STAGE_ID', 'TOURNAMENT_TYPE', 'TOURNAMENT_ID', 'SOURCE_TYPE', 'HAS_LIVE_TABLE', 'STANDING_INFO', 'TEMPLATE_ID', 'TOURNAMENT_STAGE_TYPE', 'SHORT_NAME', 'URL', 'TOURNAMENT_IMAGE', 'SORT', 'STAGES_COUNT', 'ZKL', 'ZKU', 'TOURNAMENT_SEASON_ID', 'CATEGORY_NAME', 'EVENTS'])

# %%
json['DATA'][1]['EVENTS'][0]
# Out:
# {'EVENT_ID': 'zBSk643E',
#  'START_TIME': 1669316400,
#  'START_UTIME': 1669316400,
#  'STAGE_TYPE': 'SCHEDULED',
#  'MERGE_STAGE_TYPE': 'SCHEDULED',
#  'STAGE': 'SCHEDULED',
#  'SORT': 'Brazil',
#  'ROUND': 'Group G',
#  'ERN': 'Round 1',
#  'GN': None,
#  'VISIBLE_RUN_RATE': 0,
#  'HAS_LINEPS': 0,
#  'GAME_TIME': '-1',
#  'WL': None,
#  'WE': None,
#  'WQ': None,
#  'SHORTNAME_HOME': 'BRA',
#  'HOME_PARTICIPANT_IDS': ['I9l9aqLq'],
#  'HOME_PARTICIPANT_TYPES': [17],
#  'NJ': None,
#  'NJL': None,
#  'HOME_NAME': 'Brazil',
#  'FH': 'Brazil',
#  'HOME_EVENT_PARTICIPANT_ID': '2LPiTZeE',
#  'HOME_SLUG': 'brazil',
#  'HOME_GOAL_VAR': 0,
#  'HOME_IMAGES': ['https://www.flashscore.com/res/image/data/hCaVxehl-4GYKBvjG.png'],
#  'IMM': '8Kl6iq0i',
#  'IMW': '200',
#  'IMP': 'r1dE7dpG-0jpFTnz3.png',
#  'IME': None,
#  'SHORTNAME_AWAY': 'SRB',
#  'AWAY_PARTICIPANT_IDS': ['8Kl6iq0i'],
#  'AWAY_PARTICIPANT_TYPES': [17],
#  'AWAY_NAME': 'Serbia',
#  'FK': 'Serbia',
# ...

# %%
import requests

url = "https://flashscore.p.rapidapi.com/v1/teams/squad"

querystring = {"team_id":"I9l9aqLq","sport_id":"1","locale":"en_GB"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "flashscore.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"DATA":[{"GROUP_ID":12,"GROUP_LABEL":"Goalkeepers","ITEMS":[{"PLAYER_ID":"UZrQ3bwP","PLAYER_NAME":"Alisson","PLAYER_TYPE_ID":"GOALKEEPER","PLAYER_JERSEY_NUMBER":1,"PLAYER_FLAG_ID":39,"PLAYER_IMAGE_PATH":"https://www.flashscore.com/res/image/data/vi2uSedM-t2koCZPA.png"},{"PLAYER_ID":"UDODA71I","PLAYER_NAME":"Ederson","PLAYER_TYPE_ID":"GOALKEEPER","PLAYER_JERSEY_NUMBER":31,"PLAYER_FLAG_ID":39,"PLAYER_IMAGE_PATH":"https://www.flashscore.com/res/image/data/E9pFs3xS-z7Z3VTfK.png"},{"PLAYER_ID":"EF7GKauI","PLAYER_NAME":"Everson","PLAYER_TYPE_ID":"GOALKEEPER","PLAYER_JERSEY_NUMBER":22,"PLAYER_FLAG_ID":39,"PLAYER_IMAGE_PATH":"https://www.flashscore.com/res/image/data/hUdHspg5-bg01W5cA.png"},{"PLAYER_ID":"0CZb20j1","PLAYER_NAME":"Santos","PLAYER_TYPE_ID":"GOALKEEPER","PLAYER_JERSEY_NUMBER":20,"PLAYER_FLAG_ID":39,"PLAYER_IMAGE_PATH":"https://www.flashscore.com/res/image/data/baPhcdWg-SKx8fZ3U.png"},{"PLAYER_ID":"Ac1mqDdC","PLAYER_NAME":"Weverton","PLAYER_TYPE_ID":"GOALKEEPER","PLAYER_JERSEY_N
# ...

# %%
json = response.json()
json
# Out:
# {'DATA': [{'GROUP_ID': 12,
#    'GROUP_LABEL': 'Goalkeepers',
#    'ITEMS': [{'PLAYER_ID': 'UZrQ3bwP',
#      'PLAYER_NAME': 'Alisson',
#      'PLAYER_TYPE_ID': 'GOALKEEPER',
#      'PLAYER_JERSEY_NUMBER': 1,
#      'PLAYER_FLAG_ID': 39,
#      'PLAYER_IMAGE_PATH': 'https://www.flashscore.com/res/image/data/vi2uSedM-t2koCZPA.png'},
#     {'PLAYER_ID': 'UDODA71I',
#      'PLAYER_NAME': 'Ederson',
#      'PLAYER_TYPE_ID': 'GOALKEEPER',
#      'PLAYER_JERSEY_NUMBER': 31,
#      'PLAYER_FLAG_ID': 39,
#      'PLAYER_IMAGE_PATH': 'https://www.flashscore.com/res/image/data/E9pFs3xS-z7Z3VTfK.png'},
#     {'PLAYER_ID': 'EF7GKauI',
#      'PLAYER_NAME': 'Everson',
#      'PLAYER_TYPE_ID': 'GOALKEEPER',
#      'PLAYER_JERSEY_NUMBER': 22,
#      'PLAYER_FLAG_ID': 39,
#      'PLAYER_IMAGE_PATH': 'https://www.flashscore.com/res/image/data/hUdHspg5-bg01W5cA.png'},
#     {'PLAYER_ID': '0CZb20j1',
#      'PLAYER_NAME': 'Santos',
#      'PLAYER_TYPE_ID': 'GOALKEEPER',
# ...

# %%
json['DATA'][3]
# Out:
# {'GROUP_ID': 15,
#  'GROUP_LABEL': 'Forwards',
#  'ITEMS': [{'PLAYER_ID': 'dIe4SZEK',
#    'PLAYER_NAME': 'Antony',
#    'PLAYER_TYPE_ID': 'FORWARD',
#    'PLAYER_JERSEY_NUMBER': 11,
#    'PLAYER_FLAG_ID': 39,
#    'PLAYER_IMAGE_PATH': 'https://www.flashscore.com/res/image/data/OOkJqtYg-zakuKGhT.png'},
#   {'PLAYER_ID': '08kDzY6h',
#    'PLAYER_NAME': 'Barbosa Gabriel',
#    'PLAYER_TYPE_ID': 'FORWARD',
#    'PLAYER_JERSEY_NUMBER': 9,
#    'PLAYER_FLAG_ID': 39,
#    'PLAYER_IMAGE_PATH': 'https://www.flashscore.com/res/image/data/Yo0QZUYA-b9WDKsH8.png'},
#   {'PLAYER_ID': 'viMb6g9n',
#    'PLAYER_NAME': 'Jesus Gabriel',
#    'PLAYER_TYPE_ID': 'FORWARD',
#    'PLAYER_JERSEY_NUMBER': 9,
#    'PLAYER_FLAG_ID': 39,
#    'PLAYER_IMAGE_PATH': 'https://www.flashscore.com/res/image/data/QXmNnjFG-Sdl6420l.png'},
#   {'PLAYER_ID': 'dITe5M88',
#    'PLAYER_NAME': 'Martinelli Gabriel',
#    'PLAYER_TYPE_ID': 'FORWARD',
#    'PLAYER_JERSEY_NUMBER': 35,
#    'PLAYER_FLAG_ID': 39,
# ...

# %%
#neymar player events
import requests

url = "https://flashscore.p.rapidapi.com/v1/players/alt-events"

querystring = {"player_id":"jNOPwl3h","locale":"en_GB"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "flashscore.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"DATA":[{"EVENT_ID":"g_1_QmiqYRqA","EVENT_ENCODED_ID":"QmiqYRqA","STATS":{"595":{"VALUE":"90'","TYPE":"minutes-played"},"596":{"VALUE":"1","TYPE":"goal"},"599":{"VALUE":"1","TYPE":"yellow-card"},"600":{"VALUE":"0","TYPE":"grey"},"541":{"VALUE":"0","TYPE":"grey"}},"ABSENCE_CATEGORY":"","ABSENCE_TYPE_TEXT":null,"ABSENCE_ICON":null,"EVENT_START_TIME":"06.06.22","HOME_SCORE":0,"HOME_WIN":false,"AWAY_WIN":true,"HOME_PARTICIPANT_NAME":"Japan","HOME_PARTICIPANT3_CHAR_NAME":"JAP","HOME_PARTICIPANT_URL":"japan","HOME_PARTICIPANT_LOGO_URL":"Crg4NaGG-U7JSUInL.png","AWAY_SCORE":1,"AWAY_PARTICIPANT_NAME":"Brazil","AWAY_PARTICIPANT3_CHAR_NAME":"BRA","AWAY_PARTICIPANT_URL":"brazil","AWAY_PARTICIPANT_LOGO_URL":"hCaVxehl-4GYKBvjG.png","TOURNAMENT_TEMPLATE_SHORT_CODE":"FI","TOURNAMENT_TITLE":"Friendly International (World)","TOURNAMENT_SEASON":"2022-2022","FLAG_ID":8,"FLAG_NAME":"World","WIN_LOSE_CLASS_SUFFIX":"w","WIN_LOSE_TITLE":"Win","WIN_LOSE_SHORT":"W","TOURNAMENT_URL":"/football/world/friendly-
# ...

# %%
json = response.json()
json
# Out:
# {'DATA': [{'EVENT_ID': 'g_1_QmiqYRqA',
#    'EVENT_ENCODED_ID': 'QmiqYRqA',
#    'STATS': {'595': {'VALUE': "90'", 'TYPE': 'minutes-played'},
#     '596': {'VALUE': '1', 'TYPE': 'goal'},
#     '599': {'VALUE': '1', 'TYPE': 'yellow-card'},
#     '600': {'VALUE': '0', 'TYPE': 'grey'},
#     '541': {'VALUE': '0', 'TYPE': 'grey'}},
#    'ABSENCE_CATEGORY': '',
#    'ABSENCE_TYPE_TEXT': None,
#    'ABSENCE_ICON': None,
#    'EVENT_START_TIME': '06.06.22',
#    'HOME_SCORE': 0,
#    'HOME_WIN': False,
#    'AWAY_WIN': True,
#    'HOME_PARTICIPANT_NAME': 'Japan',
#    'HOME_PARTICIPANT3_CHAR_NAME': 'JAP',
#    'HOME_PARTICIPANT_URL': 'japan',
#    'HOME_PARTICIPANT_LOGO_URL': 'Crg4NaGG-U7JSUInL.png',
#    'AWAY_SCORE': 1,
#    'AWAY_PARTICIPANT_NAME': 'Brazil',
#    'AWAY_PARTICIPANT3_CHAR_NAME': 'BRA',
#    'AWAY_PARTICIPANT_URL': 'brazil',
#    'AWAY_PARTICIPANT_LOGO_URL': 'hCaVxehl-4GYKBvjG.png',
#    'TOURNAMENT_TEMPLATE_SHORT_CODE': 'FI',
# ...

# %%
json['DATA'][0]
# Out:
# {'EVENT_ID': 'g_1_QmiqYRqA',
#  'EVENT_ENCODED_ID': 'QmiqYRqA',
#  'STATS': {'595': {'VALUE': "90'", 'TYPE': 'minutes-played'},
#   '596': {'VALUE': '1', 'TYPE': 'goal'},
#   '599': {'VALUE': '1', 'TYPE': 'yellow-card'},
#   '600': {'VALUE': '0', 'TYPE': 'grey'},
#   '541': {'VALUE': '0', 'TYPE': 'grey'}},
#  'ABSENCE_CATEGORY': '',
#  'ABSENCE_TYPE_TEXT': None,
#  'ABSENCE_ICON': None,
#  'EVENT_START_TIME': '06.06.22',
#  'HOME_SCORE': 0,
#  'HOME_WIN': False,
#  'AWAY_WIN': True,
#  'HOME_PARTICIPANT_NAME': 'Japan',
#  'HOME_PARTICIPANT3_CHAR_NAME': 'JAP',
#  'HOME_PARTICIPANT_URL': 'japan',
#  'HOME_PARTICIPANT_LOGO_URL': 'Crg4NaGG-U7JSUInL.png',
#  'AWAY_SCORE': 1,
#  'AWAY_PARTICIPANT_NAME': 'Brazil',
#  'AWAY_PARTICIPANT3_CHAR_NAME': 'BRA',
#  'AWAY_PARTICIPANT_URL': 'brazil',
#  'AWAY_PARTICIPANT_LOGO_URL': 'hCaVxehl-4GYKBvjG.png',
#  'TOURNAMENT_TEMPLATE_SHORT_CODE': 'FI',
#  'TOURNAMENT_TITLE': 'Friendly International (World)',
#  'TOURNAMENT_SEASON': '2022-2022',
# ...

# %%
#neymar player data
import requests

url = "https://flashscore.p.rapidapi.com/v1/players/data"

querystring = {"sport_id":"1","player_id":"jNOPwl3h","locale":"en_GB"}

headers = {
	"X-RapidAPI-Key": API_KEY,
	"X-RapidAPI-Host": "flashscore.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"DATA":{"ID":"jNOPwl3h","LAYOUT":"RESULTS_FIXTURES","SHORT_NAME":"Neymar","GENDER_ID":1,"COUNTRY_ID":39,"COUNTRY_NAME":"Brazil","IMAGE_PATH":"https://www.flashscore.com/res/image/data/MXnuaUZA-67kSFkxj.png","IMM":"jNOPwl3h","IMW":"100","IMP":"MXnuaUZA-67kSFkxj.png","IME":"","IMAGE_TABLE_PATH":null,"NAME":"Neymar","BIRTHDAY_TIME":"697248000","TYPE_ID":15,"TYPE_NAME":"forward","TAB":"N","PARENT_NAME":"Paris SG","TEAM_ID":"CjhkPw0k","TEAM_PARTICIPANT_TYPE":2,"TEAM_IMAGE":"https://www.flashscore.com/res/image/data/EskJufg5-lIDJVsTo.png","TEAM_NAME":"Paris SG","SPORT_ID":1}}

# %%
json = response.json()
json
# Out:
# {'DATA': {'ID': 'jNOPwl3h',
#   'LAYOUT': 'RESULTS_FIXTURES',
#   'SHORT_NAME': 'Neymar',
#   'GENDER_ID': 1,
#   'COUNTRY_ID': 39,
#   'COUNTRY_NAME': 'Brazil',
#   'IMAGE_PATH': 'https://www.flashscore.com/res/image/data/MXnuaUZA-67kSFkxj.png',
#   'IMM': 'jNOPwl3h',
#   'IMW': '100',
#   'IMP': 'MXnuaUZA-67kSFkxj.png',
#   'IME': '',
#   'IMAGE_TABLE_PATH': None,
#   'NAME': 'Neymar',
#   'BIRTHDAY_TIME': '697248000',
#   'TYPE_ID': 15,
#   'TYPE_NAME': 'forward',
#   'TAB': 'N',
#   'PARENT_NAME': 'Paris SG',
#   'TEAM_ID': 'CjhkPw0k',
#   'TEAM_PARTICIPANT_TYPE': 2,
#   'TEAM_IMAGE': 'https://www.flashscore.com/res/image/data/EskJufg5-lIDJVsTo.png',
#   'TEAM_NAME': 'Paris SG',
#   'SPORT_ID': 1}}
